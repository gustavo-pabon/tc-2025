# %% [markdown]
# <h1 align="center">
#     <img
#         src="./img/Microsoft-Logo.png"
#         width="400"/>
# </h1>
# <h1 align="center">
#     <b>Practical Guide</b>
# </h1>
# <h4 align="center">
#     for the creation of an AI Solution</a>
# </h4>
#
# # What to expect
#
# * **Part 0:** *Installing libraries*
# * **Part 1:** *Converting the source documents to markdown*
# * **Part 2:** *Creating the Index and the Query Engine*
# * **Part 3:** *Evaluating the model*

# %% [markdown]
# # Part 0 - Install and import Libraries

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (25.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymupdf openai tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymupdf in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.25.5)
# Requirement already satisfied: openai in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.77.0)
# Requirement already satisfied: tqdm in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdf2image openai python-dotenv tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pdf2image in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.17.0)
# Requirement already satisfied: openai in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.77.0)
# Requirement already satisfied: python-dotenv in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.1.0)
# Requirement already satisfied: tqdm in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.67.1)
# Requirement already satisfied: pillow in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pdf2image) (11.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade llama-index
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: llama-index in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.12.34)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.34 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.12.34.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.3.38)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.77.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (3.11.18)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (2.1.2)
# Requirement already satisfied: dataclasses-json in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (2025.3.0)
# Requirement already satisfied: httpx in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (3.4.2)
# Requirement already satisfied: numpy in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (2.2.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.34->llama-index) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13,>=0.12.34->llama-index) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.34->llama-index) (1.20.0)
# Requirement already satisfied: griffe in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.34->llama-index) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.34->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.34->llama-index) (4.3.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pandas in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.4.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (3.6)
# Requirement already satisfied: certifi in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx->llama-index-core<0.13,>=0.12.34->llama-index) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx->llama-index-core<0.13,>=0.12.34->llama-index) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.34->llama-index) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.34->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.34->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.34->llama-index) (0.4.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13,>=0.12.34->llama-index) (0.4.6)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.19)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.21)
# Requirement already satisfied: llama-cloud-services>=0.6.21 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.21)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-cloud-services>=0.6.21->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.1.8)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-cloud-services>=0.6.21->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: joblib in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>3.8.1->llama-index) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.34->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.34->llama-index) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.34->llama-index) (3.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.34->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.34->llama-index) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.34->llama-index) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.34->llama-index) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.16.0)

# %%
pip install torch sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.7.0)
# Requirement already satisfied: sentence-transformers in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.1.0)
# Requirement already satisfied: filelock in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (80.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->sentence-transformers) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hf_xet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hf_xet in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install llama_index.embeddings.azure_openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama_index.embeddings.azure_openai in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.3.2)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama_index.embeddings.azure_openai) (0.12.34.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama_index.embeddings.azure_openai) (0.3.1)
# Requirement already satisfied: llama-index-llms-azure-openai<0.4.0,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama_index.embeddings.azure_openai) (0.3.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.11.18)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.1.2)
# Requirement already satisfied: dataclasses-json in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2025.3.0)
# Requirement already satisfied: httpx in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.27.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.9.1)
# Requirement already satisfied: numpy in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.2.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.20.0)
# Requirement already satisfied: griffe in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.1.6)
# Requirement already satisfied: platformdirs in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (4.3.7)
# Requirement already satisfied: openai>=1.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.77.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.21.0)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (0.3.38)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (44.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (3.6)
# Requirement already satisfied: certifi in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (0.4.6)
# Requirement already satisfied: six>=1.11.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-core>=1.31.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.4.0,>=0.3.0->llama_index.embeddings.azure_openai) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2.4.0)
# Requirement already satisfied: click in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (8.1.8)
# Requirement already satisfied: joblib in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (2024.11.6)
# Requirement already satisfied: greenlet>=1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama_index.embeddings.azure_openai) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (8.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets) (8.22.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: decorator in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ragas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ragas in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.2.15)
# Requirement already satisfied: numpy in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (2.2.5)
# Requirement already satisfied: datasets in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (3.5.1)
# Requirement already satisfied: tiktoken in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (0.9.0)
# Requirement already satisfied: langchain in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (0.3.25)
# Requirement already satisfied: langchain-core in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (0.3.58)
# Requirement already satisfied: langchain-community in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (0.3.23)
# Requirement already satisfied: langchain_openai in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (0.3.16)
# Requirement already satisfied: nest-asyncio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (1.4.4)
# Requirement already satisfied: pydantic>=2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (2.11.4)
# Requirement already satisfied: openai>1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (1.77.0)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ragas) (5.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai>1->ragas) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.6)
# Requirement already satisfied: certifi in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ragas) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ragas) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ragas) (0.4.0)
# Requirement already satisfied: colorama in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>4->openai>1->ragas) (0.4.6)
# Requirement already satisfied: filelock in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (2.32.3)
# Requirement already satisfied: xxhash in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ragas) (2025.3.0)
# Requirement already satisfied: aiohttp in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (3.11.18)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (0.30.2)
# Requirement already satisfied: packaging in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datasets->ragas) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp->datasets->ragas) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.32.2->datasets->ragas) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.32.2->datasets->ragas) (2.4.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain->ragas) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain->ragas) (0.3.42)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain->ragas) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain-core->ragas) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langsmith<0.4,>=0.1.17->langchain->ragas) (0.23.0)
# Requirement already satisfied: greenlet>=1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain->ragas) (3.2.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain-community->ragas) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from langchain-community->ragas) (0.4.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.1.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tiktoken->ragas) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->datasets->ragas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->datasets->ragas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->datasets->ragas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ricastro\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Part 1 - Loading and converting documents to *markdown*
# In this section we will process the documents available and convert them to the markdown format. This includes using LLM to describe images.

# %%
import base64
import os
from tqdm import tqdm
from openai import AzureOpenAI
from pdf2image import convert_from_path
from dotenv import load_dotenv
from PyPDF2 import PdfReader
import gc
import os

# %% [markdown]
# ## Load .env variables

# %%
# This reads the .env file and sets the environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Client to connect to Azure OpenAI

# %%
# Connect to Azure OpenAI
client = AzureOpenAI(
    api_key=os.environ["OPENAI_API_KEY"],
    api_version=os.environ["OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"]
)

# %% [markdown]
# ## A function to describe images (!!)
# This represents the first major change. Instead of only working with whatever was extracted from the pdf documents, we will pass an image and a prompt to the LLM and get back the description of the image including all the text and a description of images, tables, graohs, etc. included. The output will be in Markdown format.

# %%
# Function to describe an image
def describe_page_image(pil_image):
    # Convert PIL image to base64
    import io
    buffered = io.BytesIO()
    pil_image.save(buffered, format="PNG")
    img_base64 = base64.b64encode(buffered.getvalue()).decode()

    data_url = f"data:image/png;base64,{img_base64}"

    prompt = """
You are a professional technical writer.
Analyze the following page from a PDF document.
Generate a detailed Markdown report that includes:
- Extracted text
- Descriptions of any plots, charts, graphs, or tables
- Any geographic references or maps
Use Markdown syntax cleanly and professionally.
"""

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {"type": "image_url", "image_url": {"url": data_url}}
                ]
            }
        ],
        temperature=0.2
    )
    return response.choices[0].message.content

# %% [markdown]
# ## From a page to a whole document
# The function below splits the passed document into chunks of 60 pages maximum and then process each page one at a time before moving to the next chunk. The results of every page and every chunk are contatenated into one single markdown document. The resulting document is finally stored for future use.
# Note that each of the pages is converted into an image, and that image is fed into the function created in the cell above.

# %%
# Function to process an entire PDF
def process_pdf_to_markdown(input_pdf_path, output_md_path, dpi=300, pages_per_chunk=60):
    print(f"🔄 Rendering PDF: {input_pdf_path}")

    # Get the total number of pages
    reader = PdfReader(input_pdf_path)
    total_pages = len(reader.pages)

    all_markdown = []

    page_num = 0
    chunk_num = 1

    while page_num < total_pages:
        end_page = min(page_num + pages_per_chunk, total_pages)
        print(f"📚 Processing chunk {chunk_num}: pages {page_num+1} to {end_page}")

        for p in tqdm(range(page_num, end_page), desc=f"Chunk {chunk_num}"):
            pil_image = convert_from_path(
                input_pdf_path,
                dpi=dpi,
                first_page=p + 1,
                last_page=p + 1
            )[0]  # Only one page returned

            page_md = f"\n\n## Page {p + 1}\n\n"

            try:
                page_description = describe_page_image(pil_image)
                page_md += page_description
            except Exception as e:
                page_md += f"_Error processing page {p + 1}: {str(e)}_"

            all_markdown.append(page_md)

            # Immediate memory cleanup
            del pil_image
            gc.collect()

        page_num = end_page
        chunk_num += 1

    # Save final Markdown
    with open(output_md_path, "w", encoding="utf-8") as f:
        f.write("\n\n".join(all_markdown))

# %% [markdown]
# ## Cycling through the documents in a folder
# The documents in the folder are cycled to be converted into markdown.

# %%
# Function to run the process for all the files in the folder
def list_files_without_extension(base_path):
    source_path = base_path+"/source_files/"
    md_path = base_path+"/md_files/"

    file_list = os.listdir(source_path)
    
    files_processed = []
    for file_name in file_list:
        if os.path.isfile(os.path.join(source_path, file_name)):
            name, ext = os.path.splitext(file_name)

            input_pdf = source_path + file_name
            output_md = md_path + name + ".md"
            process_pdf_to_markdown(input_pdf, output_md)

            files_processed.append(name)
    return files_processed

# %%
base_path = "./data"
cycle_through_documents = False  # Currently disabled as this can take close to 2h.

if cycle_through_documents:
    list_files_without_extension(base_path)

# this will take ~120+ minutes

# %% [markdown]
# # Part 2 - Index and ChatBot creation

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.core import Settings
from llama_index.core import VectorStoreIndex
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SentenceTransformerRerank
from llama_index.core.query_pipeline import QueryPipeline

import ipywidgets as widgets
from IPython.display import display, clear_output
import time

from datetime import datetime
from llama_index.core.schema import Document
import re
# import tiktoken

# %% [markdown]
# ## The indexing (!!)
# Again, big changes here. We are creater a better parser where we have much more control on what is happening, including:
# * We add the metadata `file_name` and `page_number` so it is easier to track where the information is coming from.
# * Chunk sizes
# * Chunk overlap
# * Paragraph separation
#
# After the documents are split, they are embedded using an embedding model and the index is created.

# %%
# 1. Load and prepare Documents
docs = []
input_dir = "./data/md_files/"

for fname in os.listdir(input_dir):
    if fname.endswith(".md"):
        with open(os.path.join(input_dir, fname), "r", encoding="utf-8") as f:
            content = f.read()

        # Split by page markers
        pages = re.split(r"## Page\s+(\d+)", content)

        for i in range(1, len(pages) - 1, 2):
            page_number = pages[i].strip()
            page_content = pages[i + 1].strip()

            docs.append(Document(
                text=page_content,
                metadata={"file_name": fname, "page_number": page_number}
            ))

# 2. Chunk into nodes
text_splitter = SentenceSplitter(
    chunk_size=512,
    chunk_overlap=64,
    paragraph_separator="\n\n"
)

nodes = []
for doc in docs:
    split_nodes = text_splitter.get_nodes_from_documents([doc])
    for node in split_nodes:
        node.metadata.update(doc.metadata)
        nodes.append(node)

# 3. Embed model
embed_model = AzureOpenAIEmbedding(
    model="text-embedding-3-small",
    api_key=os.environ["OPENAI_API_KEY"],
    api_version=os.environ["OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"]
)
Settings.embed_model = embed_model

# 4. Create vector index
index = VectorStoreIndex(nodes, show_progress=True)

# this will take ~4.5 minutes
# Out:
# Generating embeddings:   0%|          | 0/1032 [00:00<?, ?it/s]

# %% [markdown]
# ## The Query Engine (!!)
# Here we set up our Query Engine including the model we will use.
# * We build a *custom retriever* where we include both: vector search and keyword matching on the index we created beforeand we specify how many initial chunks to retrieve
# * We also implement a re-ranker that will select the most fitting chunks retrieved by using an additional Hugging face model.
# * We finally create the query engine using the previous steps.

# %%
# LLM Setup
llm = AzureOpenAI(
    deployment_name="gpt-4o",
    model="gpt-4o",
    temperature=0.0,
    api_key=os.environ["OPENAI_API_KEY"],
    api_version=os.environ["OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"]
)
Settings.llm = llm

# Build a custom retriever
retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=10,    # number of results to fetch
    vector_similarity_top_k=10,  # top k for vector search
    hybrid=True            # Enable hybrid retrieving (vector + keyword)
)

# Load a fast, high-quality reranker model from Hugging Face
reranker = SentenceTransformerRerank(
    top_n=5,  # how many reranked chunks to keep
    model="cross-encoder/ms-marco-MiniLM-L-6-v2"  # small and powerful
    # model="cross-encoder/ms-marco-electra-base"    # More powerful but slower
)

# Build the final query engine WITH RERANKER (NOT FORCED)
query_engine = RetrieverQueryEngine.from_args(
    retriever=retriever,
    llm=llm,
    node_postprocessors=[reranker]  # << reranker goes here
)

# %% [markdown]
# ## Testing the Query Engine (!!)
#
# We improve the interface of our simple chatbot so it also displays the sources of the chunks used to generate answers. This way it is easier, when testing, to understand where the information is coming from.

# %%
# Function to get both response and sources
def get_response(user_input):
    response = query_engine.query(user_input)
    sources = []

    if hasattr(response, "source_nodes"):
        for node in response.source_nodes[:3]:  # show top 3 sources
            meta = node.node.metadata
            sources.append({
                "file_name": meta.get("file_name", "unknown"),
                "page": meta.get("page_number", "?"),
                "snippet": node.node.text[:200].strip().replace('\n', ' ') + "..."
            })
    return response.response, sources

# Chatbot UI
def chatbot():
    output = widgets.Output()
    messages = []  # Save conversation history

    scrollable_chat = widgets.Box(
        [output],
        layout=widgets.Layout(
            width="100%",
            height="400px",
            overflow="auto",
            border="1px solid #ccc",
            padding="5px",
            display="flex",
            flex_flow="column"
        )
    )

    text_box = widgets.Text(
        placeholder="Type your message here",
        description="You:",
        style={'description_width': 'initial'},
        layout=widgets.Layout(width="70%")
    )

    submit_button = widgets.Button(
        description="Send",
        button_style="primary",
        layout=widgets.Layout(width="15%")
    )

    clear_button = widgets.Button(
        description="Clear Chat",
        button_style="warning",
        layout=widgets.Layout(width="15%")
    )

    button_box = widgets.HBox([text_box, submit_button, clear_button])
    chat_container = widgets.VBox([scrollable_chat, button_box])

    def on_submit(_):
        user_message = text_box.value.strip()
        if not user_message:
            return

        timestamp = datetime.now().strftime("%H:%M:%S")
        with output:
            display(widgets.HTML(
                f"<div style='color: blue; font-weight: bold;'>You ({timestamp}):</div> {user_message}"
            ))

        try:
            with output:
                loading = widgets.HTML("<div style='color: gray;'>Bot is thinking...</div>")
                display(loading)

            bot_response, sources = get_response(user_message)
            messages.append((user_message, bot_response, sources))  # Save conversation

            with output:
                output.clear_output(wait=True)

                # Show user message again
                display(widgets.HTML(
                    f"<div style='color: blue; font-weight: bold;'>You ({timestamp}):</div> {user_message}"
                ))

                # Show bot response with animation
                bot_output = widgets.HTML(value=f"<div style='color: green; font-weight: bold;'>Bot:</div> ")
                display(bot_output)
                full_response = ""
                for char in bot_response:
                    full_response += char
                    bot_output.value = f"<div style='color: green; font-weight: bold;'>Bot:</div> {full_response}"
                    time.sleep(0.005)

                # Show sources
                if sources:
                    display(widgets.HTML("<div style='margin-top:10px; font-weight: bold;'>Sources:</div>"))
                    for src in sources:
                        display(widgets.HTML(
                            f"<div style='font-size: 0.85em; color: gray;'>📄 {src['file_name']} – Page {src['page']}<br>"
                            f"<i>{src['snippet']}</i></div><hr style='margin:4px 0;'>"
                        ))

        except Exception as e:
            with output:
                output.clear_output(wait=True)
                display(widgets.HTML(
                    f"<div style='color: orange;'>⚠️ Sorry, I had trouble answering that.</div>"
                ))
                print(f"[ERROR] {str(e)}")  # Log to console

        text_box.value = ""

    def on_clear(_):
        output.clear_output()
        messages.clear()

    # Attach events
    submit_button.on_click(on_submit)
    text_box.on_submit(on_submit)
    clear_button.on_click(on_clear)

    display(chat_container)

# Run the chatbot
chatbot()

# how many people did microsoft provide water in india?
# Out:
# C:\Users\ricastro\AppData\Local\Temp\ipykernel_21168\3395168319.py:117: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   text_box.on_submit(on_submit)
# VBox(children=(Box(children=(Output(),), layout=Layout(border_bottom='1px solid #ccc', border_left='1px solid …

# %% [markdown]
# # Part 3 - Let's evaluate the model
# In order to be able to evaluate the model, we will use the questions available in our Q&A dataset, retrieve the answer the model produces, and compare them with the reference answers.

# %%
from llama_index.core.llama_dataset import LabelledRagDataset
from IPython.display import display, Markdown, clear_output
from ragas.dataset_schema import SingleTurnSample, EvaluationDataset

# %% [markdown]
# ## Load the Q&A dataset an show some samples

# %%
# Load some questions as example
rag_dataset = LabelledRagDataset.from_json("./data/rag_dataset.json")

num_samples = 11
samples = rag_dataset.to_pandas().loc[:num_samples-1, 'query'].values
display(Markdown("\n".join([ "* " + sample for sample in samples])))
# Out:
# * What is the objective of the Carbon Call initiative?
# * What are the three key areas that will enable the scale of sustainability solutions?
# * How many people in India did Microsoft provide water access to?
# * How many people in Indonesia did Microsoft provide water access to?
# * How many people in Brazil did Microsoft provide water access to?
# * How many people in Mexico did Microsoft provide water access to?
# * How many more acres of land does Microsoft need to protect by 2025 according to Ecosystems Chart 1?
# * What key insight was listed in page 56 of the document?
# * What key insight was listed in page 61 of the document?
# * What are the four commitments listed on page 66?
# * What is the last Key project listed under Policy and advocacy section?

# %%
rag_dataset.to_pandas().head(11)
# Out:
#                                                 query  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
#
#                                    reference_contexts  \
# 0   [In February 2022, Microsoft, ClimateWorks Fou...
# 1   [We will continue\ninvesting in three key area...
# 2   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 3   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 4   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 5   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 6   [Ecosystems Chart 1\nAchieving our target of p...
# 7   [25%\nWe are reducing idle\npower consumption\...
# 8   [100%\nOur key European\nand American\ndistrib...
# 9   [Our commitment\nUsing our voice on climate-re...
# 10  [Making green jobs, skills, and\nentrepreneurs...
#
#                                      reference_answer reference_answer_by  \
# 0   The objective of Carbon Call is to unify the w...               human
# 1   1 Advancing AI solutions for greater climate i...               human
# 2                                             309,921               human
# 3                                             225,389               human
# 4                                              16,408               human
# 5                                                 340               human
# 6                                     4998 more acres               human
# 7   25%\nWe are reducing idle power consumption of...               human
# 8   100%\nOur key European and American distributi...               human
# 9   1. Using our voice on climate-related public p...               human
# 10  Making green jobs, skills, and entrepreneurshi...               human
#
#    query_by
# 0     human
# 1     human
# 2     human
# 3     human
# 4     human
# 5     human
# 6     human
# 7     human
# 8     human
# 9     human
# 10    human

# %% [markdown]
# ## Using the Query Engine
# Now, let's calculate the responses for the dataset using the Query Engine

# %%
predictions = rag_dataset.make_predictions_with(
    predictor = query_engine,
    show_progress = True
)

# this will take ~6.5 minutes
# Out:
# 100%|██████████| 20/20 [00:47<00:00,  2.40s/it]
# 100%|██████████| 20/20 [00:49<00:00,  2.45s/it]
# 100%|██████████| 10/10 [00:30<00:00,  3.03s/it]

# %% [markdown]
# Here is an example of how the test dataset is built using the ChatBot

# %%
list_of_samples = []

for idx in range(len(rag_dataset.examples)):
    list_of_samples.append(
        SingleTurnSample (
            user_input = rag_dataset.examples[idx].query,
            reference = rag_dataset.examples[idx].reference_answer,
            response = predictions.predictions[idx].response,
            retrieved_contexts = predictions.predictions[idx].contexts
        )
    )

ragas_evaluation_dataset = EvaluationDataset(list_of_samples)
ragas_evaluation_dataset.to_pandas().head(11)
# Out:
#                                            user_input  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
#
#                                    retrieved_contexts  \
# 0   [---\n\n#### Amplifying Our Impact and Helping...
# 1   [# Microsoft Sustainability Report Analysis\n\...
# 2   [# Microsoft Sustainability Report: Water Tabl...
# 3   [# Microsoft Sustainability Report: Water Tabl...
# 4   [# Microsoft Sustainability Report: Water Tabl...
# 5   [# Microsoft Sustainability Report: Water Tabl...
# 6   [---\n\n### **Chart: Ecosystems Chart 1**\n- *...
# 7   [```markdown\n# Document Analysis Report\n\n##...
# 8   [```markdown\n# Document Analysis Report\n\n##...
# 9   [# Microsoft Sustainability Report: "How We Wo...
# 10  [### **Global**\n- Participation in *COP27* an...
#
#                                              response  \
# 0   The objective of the Carbon Call initiative is...
# 1   The three key areas that will enable the scale...
# 2   Microsoft provided water access to **309,921 p...
# 3   Microsoft provided water access to 225,389 peo...
# 4   Microsoft provided water access to 16,408 peop...
# 5   Microsoft provided water access to 340 people ...
# 6   According to Ecosystems Chart 1, Microsoft has...
# 7   The provided context does not include informat...
# 8   The context does not provide information about...
# 9   The four commitments listed on page 66 are: su...
# 10  The last key project listed under the Policy a...
#
#                                             reference
# 0   The objective of Carbon Call is to unify the w...
# 1   1 Advancing AI solutions for greater climate i...
# 2                                             309,921
# 3                                             225,389
# 4                                              16,408
# 5                                                 340
# 6                                     4998 more acres
# 7   25%\nWe are reducing idle power consumption of...
# 8   100%\nOur key European and American distributi...
# 9   1. Using our voice on climate-related public p...
# 10  Making green jobs, skills, and entrepreneurshi...

# %% [markdown]
# ## Initialize the LLM and Embedding Models for the evaluation

# %%
# To calculate the Generative AI quality metrics
from ragas.llms import LlamaIndexLLMWrapper
from ragas.embeddings import LlamaIndexEmbeddingsWrapper
from ragas.evaluation import evaluate
from ragas.run_config import RunConfig

from ragas.metrics import (
    Faithfulness,
    ContextPrecision,
    ContextRecall
)

import pandas as pd

# %% [markdown]
# Note that we will use the same `llm` and `embed_model` variables as before.

# %%
evaluator_llm = LlamaIndexLLMWrapper(llm)
evaluator_embeddings = LlamaIndexEmbeddingsWrapper(embed_model)

# %% [markdown]
# Now, with our pre defined metrics and the ground truth from the Q&A dataset, we will proceed and use RAGAS to evaluate the response

# %%
metrics = [
    Faithfulness(llm=evaluator_llm),
    ContextPrecision(llm=evaluator_llm),
    ContextRecall(llm=evaluator_llm)
]
ragas_evaluation_result = evaluate(
    dataset=ragas_evaluation_dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_embeddings,
    run_config=RunConfig(timeout=1800, max_wait=180, max_retries=20),
    show_progress=True,
    batch_size=5
)

# this will take ~6 minutes if S0 quota is not exceeded. Otherwise it will be ~8 to 20m
# Out:
# Evaluating:   0%|          | 0/150 [00:00<?, ?it/s]
# Batch 1/30:   0%|          | 0/5 [00:00<?, ?it/s]
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 5 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 7 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 5 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 7 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 7 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.8837529872056331 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 5 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.5218483287412896 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 4 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 10 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 7 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-12-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 8 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}.

# %% [markdown]
# ## Finally, let's compare the results

# %%
# Load the old and the new results
df_old_dataset = pd.read_json('./test-dataset.json', orient='records')
df_ragas_result = ragas_evaluation_result.to_pandas()

# Compare the results
values_df1 = []
values_df2 = []

for i in range(4,7):
    values_df1.append(df_ragas_result.iloc[:, i].mean())
    values_df2.append(df_old_dataset.iloc[:, i].mean())
    
# Create a table
variable_names = df_old_dataset.columns[4:]

df_results = pd.DataFrame({
    "Variable": variable_names,
    "New results": values_df1,
    "Old results": values_df2
})

# Display it nicely
display(df_results)
# Out:
#             Variable  New results  Old results
# 0       faithfulness     0.820095     0.805587
# 1  context_precision     0.558444     0.330000
# 2     context_recall     0.620000     0.283333

# %% [markdown]
# ## Create some plots to illustrate the differences

# %%
import matplotlib.pyplot as plt

# %%
 # Plot the actual vs estimated values for the selected metric

def plot_a_metric(metric, df1, df2):

    plt.figure(figsize=(20,10))
    plt.plot(df1[metric], label='New Value', marker='o', markersize = 10)
    plt.plot(df2[metric], label='Old Value', marker='s')
    
    
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title(f'{metric}: New vs Old')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# metric = "context_precision"

for metric in df_old_dataset.columns[4:]:
    plot_a_metric(metric, df_ragas_result, df_old_dataset)
